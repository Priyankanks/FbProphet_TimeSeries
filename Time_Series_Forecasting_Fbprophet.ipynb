# %%
import pandas as pd
import fbprophet
import matplotlib.pyplot as plt
import pystan
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df = pd.read_csv('airline_passengers.csv')

# %%
df.head()
# Out:
#      Month  Thousands of Passengers
# 0  1949-01                    112.0
# 1  1949-02                    118.0
# 2  1949-03                    132.0
# 3  1949-04                    129.0
# 4  1949-05                    121.0

# %%
df.isnull().sum()
# Out:
# Month                      0
# Thousands of Passengers    1
# dtype: int64

# %%
df = df.dropna()

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.columns = ['ds','y']

# %%
df.head()
# Out:
#         ds      y
# 0  1949-01  112.0
# 1  1949-02  118.0
# 2  1949-03  132.0
# 3  1949-04  129.0
# 4  1949-05  121.0

# %%
df['ds'] = pd.to_datetime(df['ds'])

# %%
df.head()
# Out:
#           ds      y
# 0 1949-01-01  112.0
# 1 1949-02-01  118.0
# 2 1949-03-01  132.0
# 3 1949-04-01  129.0
# 4 1949-05-01  121.0

# %%
from fbprophet import Prophet

# %%
model = Prophet()

# %%
model.fit(df)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model.component_modes
# Out:
# {'additive': ['yearly',
#   'additive_terms',
#   'extra_regressors_additive',
#   'holidays'],
#  'multiplicative': ['multiplicative_terms', 'extra_regressors_multiplicative']}

# %%
df.tail()
# Out:
#             ds      y
# 139 1960-08-01  606.0
# 140 1960-09-01  508.0
# 141 1960-10-01  461.0
# 142 1960-11-01  390.0
# 143 1960-12-01  432.0

# %%
future_dates = model.make_future_dataframe(periods=365)

# %%
future_dates.tail()
# Out:
#             ds
# 504 1961-11-27
# 505 1961-11-28
# 506 1961-11-29
# 507 1961-11-30
# 508 1961-12-01

# %%
pred = model.predict(future_dates)

# %%
pred.head()
# Out:
#           ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1949-01-01  106.320611   55.478932  113.057035   106.320611   106.320611
# 1 1949-02-01  108.500995   53.170924  105.713457   108.500995   108.500995
# 2 1949-03-01  110.470374   81.090676  138.641941   110.470374   110.470374
# 3 1949-04-01  112.650758   79.474128  136.767208   112.650758   112.650758
# 4 1949-05-01  114.760808   80.123090  139.805300   114.760808   114.760808
#
#    additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0      -21.941934            -21.941934            -21.941934 -21.941934
# 1      -30.714169            -30.714169            -30.714169 -30.714169
# 2       -0.475833             -0.475833             -0.475833  -0.475833
# 3       -5.203855             -5.203855             -5.203855  -5.203855
# 4       -3.825854             -3.825854             -3.825854  -3.825854
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0    -21.941934    -21.941934                   0.0
# 1    -30.714169    -30.714169                   0.0
# 2     -0.475833     -0.475833                   0.0
# 3     -5.203855     -5.203855                   0.0
# 4     -3.825854     -3.825854                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 0                         0.0                         0.0   84.378677
# 1                         0.0                         0.0   77.786826
# 2                         0.0                         0.0  109.994541
# 3                         0.0                         0.0  107.446903
# 4                         0.0                         0.0  110.934953

# %%
model.plot(pred)

# %%
model.plot_components(pred)

# %%
from fbprophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='730 days', period='180 days', horizon = '365 days')
df_cv.head()
# Out:
# INFO:fbprophet:Making 19 forecasts with cutoffs between 1951-01-18 00:00:00 and 1959-12-02 00:00:00
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-9d0fb4c2a933> in <module>
#       1 from fbprophet.diagnostics import cross_validation
# ----> 2 df_cv = cross_validation(model, initial='730 days', period='180 days', horizon = '365 days')
#       3 df_cv.head()
#
# ~\.conda\envs\virtualenv\lib\site-packages\fbprophet\diagnostics.py in cross_validation(model, horizon, period, initial, parallel, cutoffs)
#     187         predicts = [
#     188             single_cutoff_forecast(df, model, cutoff, horizon, predict_columns)
# --> 189             for cutoff in tqdm(cutoffs)
#     190         ]
#     191
#
# ~\.conda\envs\virtualenv\lib\site-packages\tqdm\notebook.py in __init__(self, *args, **kwargs)
#     240         unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     241         total = self.total * unit_scale if self.total else self.total
# --> 242         self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     243         self.container.pbar = proxy(self)
#     244         self.displayed = False
#
# ~\.conda\envs\virtualenv\lib\site-packages\tqdm\notebook.py in status_printer(_, total, desc, ncols)
#     113         # Prepare IPython progress bar
#     114         if IProgress is None:  # #187 #451 #558 #872
# --> 115             raise ImportError(
#     116                 "IProgress not found. Please update jupyter and ipywidgets."
#     117                 " See https://ipywidgets.readthedocs.io/en/stable"
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
from fbprophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-ae8cacc66608> in <module>
#       1 from fbprophet.diagnostics import performance_metrics
# ----> 2 df_p = performance_metrics(df_cv)
#       3 df_p.head()
#
# NameError: name 'df_cv' is not defined

# %%
from fbprophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='rmse')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-d1286f799722> in <module>
#       1 from fbprophet.plot import plot_cross_validation_metric
# ----> 2 fig = plot_cross_validation_metric(df_cv, metric='rmse')
#
# NameError: name 'df_cv' is not defined
